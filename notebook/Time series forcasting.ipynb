# %%
# %pip install -r requirements.txt
#!/usr/bin/env python3
# %pip install pandas matplotlib statsmodels yfinance

import pandas as pd
import matplotlib.pyplot as plt
import sys
import os

# Get the absolute path to the project directory
project_path = os.path.abspath(os.path.join(os.getcwd(), "scripts"))

from config import TICKERS, START_DATE, END_DATE, PROCESSED_DIR, FIGURES_DIR, ROLLING_WINDOW
from scripts.utils import (
    download_data,
    clean_data,
    compute_returns,
    rolling_stats,
    detect_outliers,
    adf_test,
    value_at_risk,
    sharpe_ratio,
    plot_series,
    save_dataframe
)

# Cell 2: Download & Clean Data
raw = download_data(TICKERS, START_DATE, END_DATE)
df = clean_data(raw)
df.head()

# Cell 3: Save Cleaned Data
save_dataframe(df, PROCESSED_DIR / 'cleaned_adj_close.csv')

# Cell 4: Summary Stats
df.describe()

# Cell 5: Compute Returns
returns = compute_returns(df)
returns.head()

# Cell 6: Plot Prices and Returns
plot_series(df, 'Adjusted Closing Prices', 'Price (USD)', out_path=FIGURES_DIR / 'prices.png')
plot_series(returns, 'Daily Returns', 'Daily Return', out_path=FIGURES_DIR / 'daily_returns.png')

# Cell 7: Rolling Statistics
rm, rs = rolling_stats(df, window=ROLLING_WINDOW)
rm.head(), rs.head()

# Cell 8: Outlier Detection
outliers = detect_outliers(returns)
outliers

# Cell 9: Stationarity Tests
adf_close = adf_test(df['TSLA'])
adf_returns = adf_test(returns['TSLA'])
pd.DataFrame([adf_close, adf_returns], index=['TSLA_Close', 'TSLA_Returns'])

# Cell 10: Risk Metrics
metrics = {}
for col in returns.columns:
    r = returns[col]
    metrics[col] = {
        'sharpe': sharpe_ratio(r),
        'var_95': value_at_risk(r, alpha=0.05),
        'mean_daily_return': r.mean(),
        'std_daily_return': r.std()
    }
# Import functions from Task 2
from task2_forecasting import (
    prepare_data,
    train_arima,
    train_lstm,
    evaluate_forecasts
)

# Example usage
# 1. Prepare data
train_data, test_data, scaler = prepare_data('TSLA', '2015-01-01', '2025-01-01')

# 2. Train ARIMA
arima_model, arima_forecast = train_arima(train_data, test_data)

# 3. Train LSTM
lstm_model, lstm_forecast = train_lstm(train_data, test_data, scaler)

# 4. Evaluate models
evaluate_forecasts(test_data, arima_forecast, lstm_forecast)
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# Requirement already satisfied: pandas in c:\users\yohanan\time-series-forecasting\.venv\lib\site-packages (2.3.1)
# Requirement already satisfied: matplotlib in c:\users\yohanan\time-series-forecasting\.venv\lib\site-packages (3.10.5)
# Requirement already satisfied: statsmodels in c:\users\yohanan\time-series-forecasting\.venv\lib\site-packages (0.14.5)
# Requirement already satisfied: yfinance in c:\users\yohanan\time-series-forecasting\.venv\lib\site-packages (0.2.65)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\yohanan\time-series-forecasting\.venv\lib\site-packages (from pandas) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\yohanan\time-series-forecasting\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\yohanan\time-series-forecasting\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\yohanan\time-series-forecasting\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\yohanan\time-series-forecasting\.venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\yohanan\time-series-forecasting\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\yohanan\time-series-forecasting\.venv\lib\site-packages (from matplotlib) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\yohanan\time-series-forecasting\.venv\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\yohanan\time-series-forecasting\.venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\yohanan\time-series-forecasting\.venv\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\yohanan\time-series-forecasting\.venv\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\yohanan\time-series-forecasting\.venv\lib\site-packages (from statsmodels) (1.16.1)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\yohanan\time-series-forecasting\.venv\lib\site-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: requests>=2.31 in c:\users\yohanan\time-series-forecasting\.venv\lib\site-packages (from yfinance) (2.32.4)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\yohanan\time-series-forecasting\.venv\lib\site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\yohanan\time-series-forecasting\.venv\lib\site-packages (from yfinance) (4.3.8)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\yohanan\time-series-forecasting\.venv\lib\site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\yohanan\time-series-forecasting\.venv\lib\site-packages (from yfinance) (3.18.2)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\yohanan\time-series-forecasting\.venv\lib\site-packages (from yfinance) (4.13.4)
# Requirement already satisfied: curl_cffi>=0.7 in c:\users\yohanan\time-series-forecasting\.venv\lib\site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\yohanan\time-series-forecasting\.venv\lib\site-packages (from yfinance) (6.31.1)
# Requirement already satisfied: websockets>=13.0 in c:\users\yohanan\time-series-forecasting\.venv\lib\site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\yohanan\time-series-forecasting\.venv\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\yohanan\time-series-forecasting\.venv\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.14.1)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\yohanan\time-series-forecasting\.venv\lib\site-packages (from curl_cffi>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\yohanan\time-series-forecasting\.venv\lib\site-packages (from curl_cffi>=0.7->yfinance) (2025.8.3)
# Requirement already satisfied: pycparser in c:\users\yohanan\time-series-forecasting\.venv\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.22)
# Requirement already satisfied: six>=1.5 in c:\users\yohanan\time-series-forecasting\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\yohanan\time-series-forecasting\.venv\lib\site-packages (from requests>=2.31->yfinance) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yohanan\time-series-forecasting\.venv\lib\site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\yohanan\time-series-forecasting\.venv\lib\site-packages (from requests>=2.31->yfinance) (2.5.0)
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 13
#      10 # Get the absolute path to the project directory
#      11 project_path = os.path.abspath(os.path.join(os.getcwd(), "scripts"))
# ---> 13 from config import TICKERS, START_DATE, END_DATE, PROCESSED_DIR, FIGURES_DIR, ROLLING_WINDOW
#      14 from scripts.utils import (
#      15     download_data,
#      16     clean_data,
#    (...)     24     save_dataframe
#      25 )
#      27 # Cell 2: Download & Clean Data
#
# ModuleNotFoundError: No module named 'config'
